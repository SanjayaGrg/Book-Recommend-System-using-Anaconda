# %% [markdown]
# # Online Book Recommendation System using item-item collaborative filtering

# %%
# importing necessary libraries
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Datasets file and dropping the unnecessary columns from the dataset

# %%
# reading the dataset files
book_ratings = pd.read_csv('ratings.csv', encoding = 'latin-1')
books = pd.read_csv('books.csv', encoding = 'latin-1')

# dropping the unnecessary columns from ratings csv file 
book_ratings = pd.merge(books,book_ratings).drop(['book_id','best_book_id','work_id','books_count','isbn13','original_publication_year','work_text_reviews_count','title','ratings_1','ratings_2','ratings_3','ratings_4','ratings_5','image_url','language_code','average_rating','ratings_count','work_ratings_count','small_image_url'],axis=1)

# head() function is used to test whether the we have right data 
book_ratings.head()
# Out:
#    id       isbn                       authors  \
# 0   2  439554934  J.K. Rowling, Mary GrandPrÃ©
# 1   2  439554934  J.K. Rowling, Mary GrandPrÃ©
# 2   2  439554934  J.K. Rowling, Mary GrandPrÃ©
# 3   2  439554934  J.K. Rowling, Mary GrandPrÃ©
# 4   2  439554934  J.K. Rowling, Mary GrandPrÃ©
#
#                              original_title  user_id  rating
# 0  Harry Potter and the Philosopher's Stone      314       3
# 1  Harry Potter and the Philosopher's Stone      588       1
# 2  Harry Potter and the Philosopher's Stone     2077       2
# 3  Harry Potter and the Philosopher's Stone     2487       3
# 4  Harry Potter and the Philosopher's Stone     2900       3

# %%
# getting recommendation based on the No.of user Ratings and preparing data table for analysis
user_ratings = book_ratings.pivot_table(index=['user_id'],columns=['original_title'],values='rating')
user_ratings.head()
# Out:
# original_title       Animal Farm & 1984   Carter Beats the Devil  \
# user_id
# 2              NaN                  NaN                      NaN
# 3              NaN                  NaN                      NaN
# 4              NaN                  NaN                      NaN
# 7              NaN                  NaN                      NaN
# 9              NaN                  NaN                      NaN
#
# original_title   The Fellowship of the Ring  \
# user_id
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 7                                       NaN
# 9                                       NaN
#
# original_title   ãããããªãã¨ãç ãå¥³ [Mekurayanagi to, nemuru onna]  \
# user_id
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 7                                                             NaN
# 9                                                             NaN
#
# original_title  'Salem's Lot The Illustrated Edition  'Tis: A Memoir  \
# user_id
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4                                                NaN             NaN
# 7                                                NaN             NaN
# 9                                                NaN             NaN
#
# original_title  1421: The Year China Discovered America  1776  31 Songs  ...  \
# user_id                                                                  ...
# 2                                                   NaN   NaN       NaN  ...
# 3                                                   NaN   NaN       NaN  ...
# 4                                                   NaN   NaN       NaN  ...
# 7                                                   NaN   NaN       NaN  ...
# 9                                                   NaN   NaN       NaN  ...
#
# original_title  á¼¸Î»Î¹Î¬Ï ; á½Î´ÏÏÏÎµÎ¹Î±  á¼¸ÏÏÎ¿ÏÎ¯Î±Î¹  \
# user_id
# 2                                           NaN                NaN
# 3                                           NaN                NaN
# 4                                           NaN                NaN
# 7                                           NaN                NaN
# 9                                           NaN                NaN
#
# original_title  á½Î´ÏÏÏÎµÎ¹Î±  á½ÏÎ­ÏÏÎµÎ¹Î±  \
# user_id
# 2                             NaN                NaN
# 3                             NaN                NaN
# 4                             NaN                NaN
# 7                             NaN                5.0
# 9                             NaN                NaN
#
# original_title  â¦trotzdem Ja zum Leben sagen: Ein Psychologe erlebt das Konzentrationslager  \
# user_id
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 7                                                             NaN
# 9                                                             NaN
#
# original_title  ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koibito]  \
# user_id
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 7                                                             NaN
# 9                                                             NaN
#
# original_title  æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]  \
# user_id
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 7                                                NaN
# 9                                                NaN
#
# original_title  ç ã®å¥³ [Suna no onna]  è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]  \
# user_id
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                    NaN                              NaN
# 7                                    NaN                              NaN
# 9                                    NaN                              NaN
#
# original_title  é¼ã®é¬éè¡å¸« 1
# user_id
# 2                                NaN
# 3                                NaN
# 4                                NaN
# 7                                NaN
# 9                                NaN
#
# [5 rows x 794 columns]

# %%
## removing the books which have less than 10 users who have rated it and filling remaining NaN with 0 in the data table.
user_ratings = user_ratings.dropna(thresh=10,axis=1).fillna(0)
user_ratings.head()
# Out:
# original_title        Animal Farm & 1984   Carter Beats the Devil  \
# user_id
# 2               0.0                  0.0                      0.0
# 3               0.0                  0.0                      0.0
# 4               0.0                  0.0                      0.0
# 7               0.0                  0.0                      0.0
# 9               0.0                  0.0                      0.0
#
# original_title   The Fellowship of the Ring  \
# user_id
# 2                                       0.0
# 3                                       0.0
# 4                                       0.0
# 7                                       0.0
# 9                                       0.0
#
# original_title   ãããããªãã¨ãç ãå¥³ [Mekurayanagi to, nemuru onna]  \
# user_id
# 2                                                             0.0
# 3                                                             0.0
# 4                                                             0.0
# 7                                                             0.0
# 9                                                             0.0
#
# original_title  'Salem's Lot The Illustrated Edition  'Tis: A Memoir  \
# user_id
# 2                                                0.0             0.0
# 3                                                0.0             0.0
# 4                                                0.0             0.0
# 7                                                0.0             0.0
# 9                                                0.0             0.0
#
# original_title  1421: The Year China Discovered America  1776  31 Songs  ...  \
# user_id                                                                  ...
# 2                                                   0.0   0.0       0.0  ...
# 3                                                   0.0   0.0       0.0  ...
# 4                                                   0.0   0.0       0.0  ...
# 7                                                   0.0   0.0       0.0  ...
# 9                                                   0.0   0.0       0.0  ...
#
# original_title  á¼¸Î»Î¹Î¬Ï ; á½Î´ÏÏÏÎµÎ¹Î±  á¼¸ÏÏÎ¿ÏÎ¯Î±Î¹  \
# user_id
# 2                                           0.0                0.0
# 3                                           0.0                0.0
# 4                                           0.0                0.0
# 7                                           0.0                0.0
# 9                                           0.0                0.0
#
# original_title  á½Î´ÏÏÏÎµÎ¹Î±  á½ÏÎ­ÏÏÎµÎ¹Î±  \
# user_id
# 2                             0.0                0.0
# 3                             0.0                0.0
# 4                             0.0                0.0
# 7                             0.0                5.0
# 9                             0.0                0.0
#
# original_title  â¦trotzdem Ja zum Leben sagen: Ein Psychologe erlebt das Konzentrationslager  \
# user_id
# 2                                                             0.0
# 3                                                             0.0
# 4                                                             0.0
# 7                                                             0.0
# 9                                                             0.0
#
# original_title  ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koibito]  \
# user_id
# 2                                                             0.0
# 3                                                             0.0
# 4                                                             0.0
# 7                                                             0.0
# 9                                                             0.0
#
# original_title  æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]  \
# user_id
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
# 7                                                0.0
# 9                                                0.0
#
# original_title  ç ã®å¥³ [Suna no onna]  è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]  \
# user_id
# 2                                    0.0                              0.0
# 3                                    0.0                              0.0
# 4                                    0.0                              0.0
# 7                                    0.0                              0.0
# 9                                    0.0                              0.0
#
# original_title  é¼ã®é¬éè¡å¸« 1
# user_id
# 2                                0.0
# 3                                0.0
# 4                                0.0
# 7                                0.0
# 9                                0.0
#
# [5 rows x 794 columns]

# %% [markdown]
# ## Standardizing
# #### - process of reducing the mean of all ratings given by the user to zero and dividing it by the range.

# %%
## standardizing the vaalues
def standardize(row):
    new_row = (row - row.mean())/(row.max()-row.min())
    return new_row

ratings_standardize = user_ratings.apply(standardize)
ratings_standardize.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-31-312ac1531ac1> in <module>
#       4     return new_row
#       5
# ----> 6 ratings_standardize = user_ratings.apply(standardize)
#       7 ratings_standardize.head()
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     277
#     278         # wrap results
# --> 279         return self.wrap_results(results, res_index)
#     280
#     281     def apply_series_generator(self) -> Tuple[ResType, "Index"]:
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\apply.py in wrap_results(self, results, res_index)
#     301         # see if we can infer the results
#     302         if len(results) > 0 and 0 in results and is_sequence(results[0]):
# --> 303             return self.wrap_results_for_axis(results, res_index)
#     304
#     305         # dict of scalars
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\apply.py in wrap_results_for_axis(self, results, res_index)
#     359
#     360         try:
# --> 361             result = self.obj._constructor(data=results)
#     362         except ValueError as err:
#     363             if "arrays must all be same length" in str(err):
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      93     axes = [columns, index]
#      94
# ---> 95     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      96
#      97
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1699     arrays = [x if not isinstance(x, ABCPandasArray) else x.to_numpy() for x in arrays]
#    1700     try:
# -> 1701         blocks = _form_blocks(arrays, names, axes)
#    1702         mgr = BlockManager(blocks, axes)
#    1703         mgr._consolidate_inplace()
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _form_blocks(arrays, names, axes)
#    1757     blocks: List[Block] = []
#    1758     if len(items_dict["FloatBlock"]):
# -> 1759         float_blocks = _multi_blockify(items_dict["FloatBlock"])
#    1760         blocks.extend(float_blocks)
#    1761
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _multi_blockify(tuples, dtype)
#    1850     for dtype, tup_block in grouper:
#    1851
# -> 1852         values, placement = _stack_arrays(list(tup_block), dtype)
#    1853
#    1854         block = make_block(values, placement=placement, ndim=2)
#
# D:\Anaconda\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1878     shape = (len(arrays),) + _shape_compat(first)
#    1879
# -> 1880     stacked = np.empty(shape, dtype=dtype)
#    1881     for i, arr in enumerate(arrays):
#    1882         stacked[i] = _asarray_compat(arr)
#
# MemoryError: Unable to allocate 173. MiB for an array with shape (794, 28554) and data type float64

# %% [markdown]
# ## Using Cosine Similarity

# %%
## transpose similarity between items since we are doing item-item collaborative filtering
item_ratings = cosine_similarity(ratings_standardize.T)
print(item_ratings)
# Out:
# [[ 1.         -0.0032264  -0.00328152 ... -0.00320012 -0.00306772
#    0.00912419]
#  [-0.0032264   1.         -0.00335483 ... -0.00327161 -0.00313625
#    0.00362681]
#  [-0.00328152 -0.00335483  1.         ... -0.0033275  -0.00318983
#   -0.00341366]
#  ...
#  [-0.00320012 -0.00327161 -0.0033275  ...  1.         -0.00311071
#   -0.00332899]
#  [-0.00306772 -0.00313625 -0.00318983 ... -0.00311071  1.
#   -0.00319125]
#  [ 0.00912419  0.00362681 -0.00341366 ... -0.00332899 -0.00319125
#    1.        ]]

# %%
## calculating cosine cofficient in DataFrame
book_data_frame = pd.DataFrame(item_ratings,index=user_ratings.columns, columns=user_ratings.columns)
book_data_frame
# Out:
# original_title                                                \
# original_title
#                                                     1.000000
#  Animal Farm & 1984                                -0.003226
#  Carter Beats the Devil                            -0.003282
#  The Fellowship of the Ring                        -0.002929
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag... -0.003190
# ...                                                      ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi... -0.003237
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]               -0.003265
# ç ã®å¥³ [Suna no onna]                           -0.003200
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                    -0.003068
# é¼ã®é¬éè¡å¸« 1                                0.009124
#
# original_title                                       Animal Farm & 1984  \
# original_title
#                                                               -0.003226
#  Animal Farm & 1984                                            1.000000
#  Carter Beats the Devil                                       -0.003355
#  The Fellowship of the Ring                                   -0.002995
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...            -0.003261
# ...                                                                 ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...            -0.003309
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                           0.003703
# ç ã®å¥³ [Suna no onna]                                      -0.003272
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                               -0.003136
# é¼ã®é¬éè¡å¸« 1                                           0.003627
#
# original_title                                       Carter Beats the Devil  \
# original_title
#                                                                   -0.003282
#  Animal Farm & 1984                                               -0.003355
#  Carter Beats the Devil                                            1.000000
#  The Fellowship of the Ring                                        0.003519
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                 0.006550
# ...                                                                     ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                -0.003366
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                               0.019977
# ç ã®å¥³ [Suna no onna]                                          -0.003328
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                   -0.003190
# é¼ã®é¬éè¡å¸« 1                                              -0.003414
#
# original_title                                       The Fellowship of the Ring  \
# original_title
#                                                                       -0.002929
#  Animal Farm & 1984                                                   -0.002995
#  Carter Beats the Devil                                                0.003519
#  The Fellowship of the Ring                                            1.000000
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                    -0.002961
# ...                                                                         ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                    -0.003004
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                  -0.003030
# ç ã®å¥³ [Suna no onna]                                              -0.002970
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                       -0.002847
# é¼ã®é¬éè¡å¸« 1                                                   0.011347
#
# original_title                                       ãããããªãã¨ãç ãå¥³ [Mekurayanagi to, nemuru onna]  \
# original_title
#                                                                                             -0.003190
#  Animal Farm & 1984                                                                         -0.003261
#  Carter Beats the Devil                                                                      0.006550
#  The Fellowship of the Ring                                                                 -0.002961
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                                           1.000000
# ...                                                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                                          -0.003272
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                                        -0.003300
# ç ã®å¥³ [Suna no onna]                                                                    -0.003234
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                             -0.003101
# é¼ã®é¬éè¡å¸« 1                                                                         0.006418
#
# original_title                                      'Salem's Lot The Illustrated Edition  \
# original_title
#                                                                                -0.002741
#  Animal Farm & 1984                                                            -0.002802
#  Carter Beats the Devil                                                        -0.002850
#  The Fellowship of the Ring                                                    -0.002544
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                             -0.002770
# ...                                                                                  ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                             -0.002811
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                           -0.002835
# ç ã®å¥³ [Suna no onna]                                                        0.010491
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                -0.002664
# é¼ã®é¬éè¡å¸« 1                                                           -0.002851
#
# original_title                                      'Tis: A Memoir  \
# original_title
#                                                          -0.003237
#  Animal Farm & 1984                                       0.006308
#  Carter Beats the Devil                                  -0.003366
#  The Fellowship of the Ring                              -0.003005
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...       -0.003272
# ...                                                            ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...        0.003690
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                     -0.003349
# ç ã®å¥³ [Suna no onna]                                 -0.003283
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                          -0.003147
# é¼ã®é¬éè¡å¸« 1                                      0.011754
#
# original_title                                      1421: The Year China Discovered America  \
# original_title
#                                                                                   -0.003216
#  Animal Farm & 1984                                                               -0.003288
#  Carter Beats the Devil                                                           -0.003344
#  The Fellowship of the Ring                                                        0.018109
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                                -0.003251
# ...                                                                                     ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                                -0.003299
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                              -0.003327
# ç ã®å¥³ [Suna no onna]                                                          -0.003261
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                   -0.003126
# é¼ã®é¬éè¡å¸« 1                                                              -0.003346
#
# original_title                                          1776  31 Songs  ...  \
# original_title                                                          ...
#                                                    -0.003253 -0.003235  ...
#  Animal Farm & 1984                                -0.003325 -0.003308  ...
#  Carter Beats the Devil                            -0.003382 -0.003364  ...
#  The Fellowship of the Ring                         0.035126  0.013546  ...
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag... -0.003287 -0.003270  ...
# ...                                                      ...       ...  ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi... -0.003336  0.137994  ...
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]               -0.003364 -0.003347  ...
# ç ã®å¥³ [Suna no onna]                           -0.003298 -0.003281  ...
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                    -0.003162 -0.003145  ...
# é¼ã®é¬éè¡å¸« 1                                0.010087  0.036479  ...
#
# original_title                                      á¼¸Î»Î¹Î¬Ï ; á½Î´ÏÏÏÎµÎ¹Î±  \
# original_title
#                                                                           -0.003205
#  Animal Farm & 1984                                                        0.005664
#  Carter Beats the Devil                                                   -0.003333
#  The Fellowship of the Ring                                                0.039413
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                         0.013121
# ...                                                                             ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                         0.004859
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                      -0.003316
# ç ã®å¥³ [Suna no onna]                                                  -0.003250
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                           -0.003116
# é¼ã®é¬éè¡å¸« 1                                                      -0.003334
#
# original_title                                      á¼¸ÏÏÎ¿ÏÎ¯Î±Î¹  \
# original_title
#                                                              0.010106
#  Animal Farm & 1984                                         -0.003256
#  Carter Beats the Devil                                     -0.003312
#  The Fellowship of the Ring                                  0.011607
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...          -0.003219
# ...                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...          -0.003267
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                        -0.003295
# ç ã®å¥³ [Suna no onna]                                     0.004313
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                             -0.003096
# é¼ã®é¬éè¡å¸« 1                                        -0.000893
#
# original_title                                      á½Î´ÏÏÏÎµÎ¹Î±  \
# original_title
#                                                             -0.003191
#  Animal Farm & 1984                                         -0.003262
#  Carter Beats the Devil                                      0.016673
#  The Fellowship of the Ring                                  0.021682
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...          -0.003225
# ...                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...          -0.003273
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                        -0.003301
# ç ã®å¥³ [Suna no onna]                                    -0.003236
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                             -0.003102
# é¼ã®é¬éè¡å¸« 1                                         0.005383
#
# original_title                                      á½ÏÎ­ÏÏÎµÎ¹Î±  \
# original_title
#                                                             -0.003251
#  Animal Farm & 1984                                         -0.003323
#  Carter Beats the Devil                                     -0.003380
#  The Fellowship of the Ring                                  0.006880
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...          -0.003286
# ...                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...          -0.003334
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                        -0.003363
# ç ã®å¥³ [Suna no onna]                                     0.007875
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                             -0.003160
# é¼ã®é¬éè¡å¸« 1                                         0.010061
#
# original_title                                      â¦trotzdem Ja zum Leben sagen: Ein Psychologe erlebt das Konzentrationslager  \
# original_title
#                                                                                             -0.003246
#  Animal Farm & 1984                                                                         -0.003319
#  Carter Beats the Devil                                                                      0.005396
#  The Fellowship of the Ring                                                                 -0.003013
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                                          -0.003281
# ...                                                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                                          -0.003330
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                                         0.007549
# ç ã®å¥³ [Suna no onna]                                                                    -0.003292
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                             -0.003156
# é¼ã®é¬éè¡å¸« 1                                                                        -0.003377
#
# original_title                                      ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koibito]  \
# original_title
#                                                                                             -0.003237
#  Animal Farm & 1984                                                                         -0.003309
#  Carter Beats the Devil                                                                     -0.003366
#  The Fellowship of the Ring                                                                 -0.003004
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                                          -0.003272
# ...                                                                                               ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                                           1.000000
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                                        -0.003348
# ç ã®å¥³ [Suna no onna]                                                                    -0.003282
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                             -0.003146
# é¼ã®é¬éè¡å¸« 1                                                                        -0.003367
#
# original_title                                      æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]  \
# original_title
#                                                                                -0.003265
#  Animal Farm & 1984                                                             0.003703
#  Carter Beats the Devil                                                         0.019977
#  The Fellowship of the Ring                                                    -0.003030
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                             -0.003300
# ...                                                                                  ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                             -0.003348
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                            1.000000
# ç ã®å¥³ [Suna no onna]                                                       -0.003310
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                                -0.003173
# é¼ã®é¬éè¡å¸« 1                                                           -0.003396
#
# original_title                                      ç ã®å¥³ [Suna no onna]  \
# original_title
#                                                                    -0.003200
#  Animal Farm & 1984                                                -0.003272
#  Carter Beats the Devil                                            -0.003328
#  The Fellowship of the Ring                                        -0.002970
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                 -0.003234
# ...                                                                      ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                 -0.003282
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                               -0.003310
# ç ã®å¥³ [Suna no onna]                                            1.000000
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                    -0.003111
# é¼ã®é¬éè¡å¸« 1                                               -0.003329
#
# original_title                                      è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]  \
# original_title
#                                                                           -0.003068
#  Animal Farm & 1984                                                       -0.003136
#  Carter Beats the Devil                                                   -0.003190
#  The Fellowship of the Ring                                               -0.002847
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...                        -0.003101
# ...                                                                             ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...                        -0.003146
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                                      -0.003173
# ç ã®å¥³ [Suna no onna]                                                  -0.003111
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                            1.000000
# é¼ã®é¬éè¡å¸« 1                                                      -0.003191
#
# original_title                                      é¼ã®é¬éè¡å¸« 1
# original_title
#                                                                 0.009124
#  Animal Farm & 1984                                             0.003627
#  Carter Beats the Devil                                        -0.003414
#  The Fellowship of the Ring                                     0.011347
#  ãããããªãã¨ãç ãå¥³ [Mekurayanag...              0.006418
# ...                                                                  ...
# ã¹ãã¼ããã¯ã®æäºº [SupÅ«toniku no Koi...             -0.003367
# æµ·è¾ºã®ã«ãã« [Umibe no Kafuka]                           -0.003396
# ç ã®å¥³ [Suna no onna]                                       -0.003329
# è±¡ã®æ¶æ»
#  [ZÅ no shÅmetsu]                                -0.003191
# é¼ã®é¬éè¡å¸« 1                                            1.000000
#
# [794 rows x 794 columns]

# %% [markdown]
# ## Recommending similar books

# %%
## getting most similar book recommendation
## funtion to get most similar boooks
def get_similar_books(book_name,user_rating):
    similar_book = book_data_frame[book_name]*(user_rating-2.5)
    # sorting them
    similar_book = similar_book.sort_values(ascending=False)
    
    ## returning similar books
    return similar_book

# %%
## rating the books
book_reader = [("A Man Without a Country",3),
               ("Angels & Demons ",3),
               ("A Great and Terrible Beauty",2),
               ("A Lesson Before Dying",4)]

similar_books = pd.DataFrame()

for book,rating in book_reader:
    similar_books = similar_books.append(get_similar_books(book,rating),ignore_index=True)
    
similar_books.head()
recommend_books = pd.DataFrame(similar_books.sum().sort_values(ascending=False))

# %%
recommend_books.head(5)
# Out:
#                                 0
# A Lesson Before Dying    1.498375
# A Man Without a Country  0.502719
# Angels & Demons          0.502701
# Lunar Park               0.314588
# á¼¸ÏÏÎ¿ÏÎ¯Î±Î¹        0.306232
